# %% [markdown]
# #LOADING LOAN DATA
# This is Linear Regression Problem,We have to predict Interest rate

# %%
import pandas as pd
import matplotlib as plt
from sklearn import datasets
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cross_validation import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
# %matplotlib inline
df=pd.read_csv("D:\UIS-LEARN\Spring 2016/MidtermData/midterm_train.csv")

df
# Out:
# C:\Users\anusha\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2902: DtypeWarning: Columns (13,24,27,28,29,30,31,36,37,38,39,40,41,42,43,49,50) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        Interest_Rate   Loan_ID  Borrower_ID Loan_Amount_Requested  \
# 0             11.89%     54734        80364               $25,000
# 1             10.71%     55742       114426                $7,000
# 2             16.99%     57167       137225               $25,000
# 3             13.57%     57416       139635               $10,800
# 4             19.05%     58524       149512                $7,200
# 5             14.26%     59006       154254                $3,000
# 6              7.88%     61390       182594                $4,000
# 7              9.88%     62102       191024                $3,200
# 8             11.14%     65426       232106                $4,000
# ...

# %%
df.describe()
# Out:
#                Loan_ID      Borrower_ID  Monthly_Payment
# count    324477.000000    324477.000000    324477.000000
# mean   13145661.158156  14673129.804572       432.947560
# std    10875525.606518  11658777.603057       243.602423
# min       54734.000000     70699.000000        15.690000
# 25%     3703284.000000   4584336.000000       257.870000
# 50%    10122866.000000  11956936.000000       380.680000
# 75%    20751084.000000  23021691.000000       567.780000
# max    38098114.000000  40860827.000000      1409.990000

# %%
df.dtypes
# Out:
# Interest_Rate                       object
# Loan_ID                              int64
# Borrower_ID                          int64
# Loan_Amount_Requested               object
# Loan_Amount_Funded                  object
# Loan_Amount_Funded_by_Investors     object
# Initial_Loan_Term_Months            object
# Monthly_Payment                    float64
# Loan_Grade                          object
# Sub_Loan_Grade                      object
# Employer                            object
# Length_Employed                     object
# Home_Owner?                         object
# Annual_Income                       object
# Income_Verified                     object
# Month_Issued                        object
# Current_Status                      object
# Payment_Plan_Ind                    object
# Loan_Description                    object
# Purpose_Of_Loan                     object
# Loan_Title                          object
# Zip_3                               object
# ...

# %%
df.Annual_Income.describe()
# Out:
# count     274799
# unique     26011
# top        60000
# freq        5857
# Name: Annual_Income, dtype: object

# %%
df.Last_Payment_Received.value_counts()
# Out:
# Jun-15             205308
# May-15              13219
# Apr-15               7187
# Mar-15               7089
# Feb-15               5977
# Jan-15               5965
# Oct-14               5335
# Dec-14               5064
# Sep-14               4441
# Aug-14               4432
# Jul-14               4362
# Nov-14               4345
# Jun-14               3864
# May-14               3245
# Mar-14               3171
# Apr-14               3033
# Feb-14               2502
# Jan-14               2484
# Dec-13               2130
# Oct-13               1977
# Nov-13               1836
# Sep-13               1749
# Aug-13               1686
# Jul-13               1624
# May-13               1467
# Mar-13               1400
# Jun-13               1373
# Apr-13               1275
# 0                    1209
# Feb-13               1126
#                     ...
# 9.8079000005            1
# 6054.95                 1
# 26.6723999972           1
# 4.52                    1
# ...

# %%
df.columns
# Out:
# Index([u'Interest_Rate', u'Loan_ID', u'Borrower_ID', u'Loan_Amount_Requested',
#        u'Loan_Amount_Funded', u'Loan_Amount_Funded_by_Investors',
#        u'Initial_Loan_Term_Months', u'Monthly_Payment', u'Loan_Grade',
#        u'Sub_Loan_Grade', u'Employer', u'Length_Employed', u'Home_Owner?',
#        u'Annual_Income', u'Income_Verified', u'Month_Issued',
#        u'Current_Status', u'Payment_Plan_Ind', u'Loan_Description',
#        u'Purpose_Of_Loan', u'Loan_Title', u'Zip_3', u'State',
#        u'Debt_To_Income', u'Number_Delinqueny_2yrs', u'Month_Earliest_Credit',
#        u'Inquiries_Last_6Mo', u'Months_Since_Deliquency',
#        u'Months_Since_Record', u'Number_Open_Accounts', u'Public_Record_Count',
#        u'Revolving_Balance', u'Revolving_Utilization', u'Total_Accounts',
#        u'Initial_Status', u'Outstanding_Principal',
#        u'Outstanding_Principal_Remaining', u'Total_Payment',
#        u'Total_Payment_Funded', u'Total_Received', u'Total_Received_Interest',
# ...

# %% [markdown]
# Choose colums :Loan_Amount_Funded
#                Monthly_Payment
#                Loan_Grade
#                Total_Received_Late_Fees
#                Last_Payment_Received
#                Last_Payment_Total
#                Initial_Loan_Term_Month

# %%
df.head(n=1)
# Out:
#   Interest_Rate  Loan_ID  Borrower_ID Loan_Amount_Requested  \
# 0        11.89%    54734        80364               $25,000
#
#   Loan_Amount_Funded Loan_Amount_Funded_by_Investors Initial_Loan_Term_Months  \
# 0            $25,000                         $19,080                36 months
#
#    Monthly_Payment Loan_Grade Sub_Loan_Grade     ...      \
# 0            829.1          B             B4     ...
#
#   Total_Received_Late_Fees Recoveries Collection_Recovery_Fee  \
# 0                      0.0          0                     0.0
#
#   Last_Payment_Received Last_Payment_Total Next_Payment_Date  \
# 0                Oct-11            7392.08               NaN
#
#   Last_Credit_Pulled Collections_12Mo_Exclude_Med  \
# 0             Aug-12                            0
#
#   Months_Since_Last_Derogatory Policy_Code
# 0                          NaN           1
#
# [1 rows x 51 columns]

# %%
df.Total_Received_Late_Fees.value_counts()
# Out:
# 0.0                   286445
# 0.0                    21260
# 0                      10229
# 15.0                     935
# 30.0                      95
# 15.0                      44
# 15                        33
# 10000.0                   14
# 45.0                      11
# 12000.0                    9
# 16.37                      9
# 18.02                      8
# 20.6                       8
# 20000.0                    8
# 15000.0                    8
# 17.01                      7
# 21.56                      7
# 16.4                       6
# 17.41                      6
# 17.17                      6
# 24.91                      6
# 16.64                      6
# 37.39                      6
# 60.93                      6
# 17.65                      6
# 30.0                       5
# 5000.0                     5
# 16.07                      5
# 16.17                      5
# 18000.0                    5
#                        ...
# 47.5240469288              1
# ...

# %%
df.Total_Received.value_counts()
# Out:
# 10000.0     3619
# 12000.0     2816
# 15000.0     2487
# 20000.0     2236
# 8000.0      1802
# 10000       1675
# 6000.0      1560
# 35000.0     1506
# 16000.0     1402
# 5000.0      1388
# 18000.0     1303
# 12000       1297
# 24000.0     1077
# 10000.0     1020
# 6000         980
# 5000         959
# 25000.0      943
# 7000.0       914
# 15000        870
# 8000         853
# 12000.0      821
# 9000.0       786
# 14000.0      780
# 30000.0      758
# 20000        717
# 28000.0      710
# 21000.0      702
# 6000.0       663
# 5000.0       657
# 4000.0       641
#             ...
# 5778.02        1
# 2089.8         1
# 1797.49        1
# 1025.44        1
# 8235.58        1
# 2121.27        1
# 1119.57        1
# 2468.17        1
# 3732.87        1
# 5359.45        1
# 7759.14        1
# 7610.82        1
# 8233.51        1
# 2983.49        1
# 13999.91       1
# 1693.38        1
# 2405.28        1
# 5952.04        1
# 4054.82        1
# 957.85         1
# 392.28         1
# ...

# %%
df.Last_Payment_Total.value_counts()
# Out:
# 327.34      698
# 336.9       673
# 0           609
# 332.1       501
# 392.81      483
# 491.01      483
# 334.49      460
# 317.54      410
# 654.68      406
# Jun-15      404
# 608.72      385
# 498.15      350
# 635.07      344
# 304.36      342
# 168.45      341
# 269.52      337
# 163.67      335
# 404.27      334
# 330.57      332
# 289.34      329
# 261.88      323
# 505.34      323
# 456.54      322
# 338.63      318
# 323.38      317
# 321.13      317
# 673.79      313
# 332.72      310
# 381.04      308
# 625.81      308
#            ...
# 6716.35       1
# 6716.36       1
# 416.83        1
# 2597.93       1
# 167.63        1
# 545.41        1
# 18492.1       1
# 6833.11       1
# 34050.43      1
# 4415.89       1
# 17217.74      1
# 2364.26       1
# 8817.39       1
# 9292.84       1
# 6729.82       1
# 2364.23       1
# 6375.82       1
# 11369.85      1
# 108.73        1
# 894.73        1
# 8817.35       1
# 3650.36       1
# 9626.25       1
# 14553.67      1
# ...

# %%
df.Total_Received_Late_Fees.value_counts()
# Out:
# 0.0                   286445
# 0.0                    21260
# 0                      10229
# 15.0                     935
# 30.0                      95
# 15.0                      44
# 15                        33
# 10000.0                   14
# 45.0                      11
# 12000.0                    9
# 16.37                      9
# 18.02                      8
# 20.6                       8
# 20000.0                    8
# 15000.0                    8
# 17.01                      7
# 21.56                      7
# 16.4                       6
# 17.41                      6
# 17.17                      6
# 24.91                      6
# 16.64                      6
# 37.39                      6
# 60.93                      6
# 17.65                      6
# 30.0                       5
# 5000.0                     5
# 16.07                      5
# 16.17                      5
# 18000.0                    5
#                        ...
# 47.5240469288              1
# ...

# %% [markdown]
# ==>CLEANING OF DATA
# We should eliminate %,$,months,Nan values

# %% [markdown]
# Removing $ and , signs

# %% [markdown]
# --->Eliminating $ sign from column 'Loan_Amount_Funded'

# %%
ldb = df.reset_index()
LoanGiven=df['Loan_Amount_Funded'][0:]

# %%
LoanGiven
# Out:
# 0         $25,000
# 1          $7,000
# 2         $25,000
# 3         $10,800
# 4          $7,200
# 5          $3,000
# 6          $4,000
# 7          $3,200
# 8          $4,000
# 9          $2,525
# 10        $10,625
# 11         $7,500
# 12        $10,000
# 13         $3,000
# 14         $6,625
# 15        $10,000
# 16         $2,300
# 17        $15,000
# 18        $18,000
# 19         $5,000
# 20         $6,000
# 21        $11,200
# 22        $15,000
# 23        $10,000
# 24        $15,500
# 25         $9,600
# 26         $5,000
# 27         $5,000
# 28         $5,000
# 29         $5,000
#            ...
# 324447     $7,000
# 324448    $35,000
# 324449    $20,000
# 324450    $15,000
# 324451    $19,200
# 324452    $14,000
# 324453    $12,500
# 324454     $6,000
# 324455    $28,000
# 324456    $16,750
# 324457     $9,600
# 324458     $1,000
# 324459     $8,000
# 324460    $26,000
# 324461     $7,000
# 324462     $4,000
# 324463    $24,000
# 324464    $10,000
# 324465    $11,000
# ...

# %%
lg1=LoanGiven.str.replace(',', '')

# %%
lg2=lg1.str.lstrip('$')

# %%
Lg = [ x[:-1] for x in lg2 ]

# %%
df['Loan_Amount_Funded'] =lg2

# %%
df.head()
# Out:
#   Interest_Rate  Loan_ID  Borrower_ID Loan_Amount_Requested  \
# 0        11.89%    54734        80364               $25,000
# 1        10.71%    55742       114426                $7,000
# 2        16.99%    57167       137225               $25,000
# 3        13.57%    57416       139635               $10,800
# 4        19.05%    58524       149512                $7,200
#
#   Loan_Amount_Funded Loan_Amount_Funded_by_Investors Initial_Loan_Term_Months  \
# 0              25000                         $19,080                36 months
# 1               7000                            $673                36 months
# 2              25000                         $24,725                36 months
# 3              10800                         $10,692                36 months
# 4               7200                          $7,200                36 months
#
#    Monthly_Payment Loan_Grade Sub_Loan_Grade     ...      \
# 0           829.10          B             B4     ...
# ...

# %% [markdown]
# --->Eliminating $ sign from column 'Loan_Amount_Requested'

# %%
LoanRequested=df['Loan_Amount_Requested'][0:]

# %%
LoanRequested
# Out:
# 0         $25,000
# 1          $7,000
# 2         $25,000
# 3         $10,800
# 4          $7,200
# 5          $3,000
# 6          $4,000
# 7          $3,200
# 8          $4,000
# 9          $2,525
# 10        $10,625
# 11         $7,500
# 12        $10,000
# 13         $3,000
# 14         $6,625
# 15        $10,000
# 16         $2,300
# 17        $15,000
# 18        $18,000
# 19         $5,000
# 20         $6,000
# 21        $11,200
# 22        $15,000
# 23        $10,000
# 24        $15,500
# 25         $9,600
# 26         $5,000
# 27         $5,000
# 28         $5,000
# 29         $5,000
#            ...
# 324447     $7,000
# 324448    $35,000
# 324449    $20,000
# 324450    $15,000
# 324451    $19,200
# 324452    $14,000
# 324453    $12,500
# 324454     $6,000
# 324455    $28,000
# 324456    $16,750
# 324457     $9,600
# 324458     $1,000
# 324459     $8,000
# 324460    $26,000
# 324461     $7,000
# 324462     $4,000
# 324463    $24,000
# 324464    $10,000
# 324465    $11,000
# ...

# %%
lr1=LoanRequested.str.replace(',', '')

# %%
lr2=lr1.str.lstrip('$')

# %%
LR = [ x[:-1] for x in lr2 ]

# %%
df['Loan_Amount_Requested'] =LR

# %% [markdown]
# --->Eliminating $ sign from column 'Loan_Amount_Funded_by_Investors'

# %%
LI=df['Loan_Amount_Funded_by_Investors'][0:]

# %%
li1=LI.str.replace(',', '')

# %%
li2=li1.str.lstrip('$')

# %%
LI1 = [ x[:-1] for x in li2 ]

# %%
df['Loan_Amount_Funded_by_Investors'] =LI1

# %% [markdown]
# --->Removing % from Interest_Rate and converting the percentage value into float

# %%
df['Interest_Rate'] = df['Interest_Rate'].replace('%','',regex=True).astype('float')/100

# %%
df['Interest_Rate']
# Out:
# 0         0.1189
# 1         0.1071
# 2         0.1699
# 3         0.1357
# 4         0.1905
# 5         0.1426
# 6         0.0788
# 7         0.0988
# 8         0.1114
# 9         0.1221
# 10        0.1347
# 11        0.1324
# 12        0.0859
# 13        0.0714
# 14        0.0863
# 15        0.1103
# 16           NaN
# 17        0.0894
# 18        0.1039
# 19        0.1513
# 20        0.0800
# 21        0.1533
# 22        0.0863
# 23        0.1355
# 24           NaN
# 25        0.1229
# 26        0.0901
# 27        0.0743
# 28        0.0743
# 29        0.0743
#            ...
# 324447    0.0819
# 324448    0.1924
# 324449    0.1199
# 324450    0.1299
# 324451    0.0819
# 324452    0.1924
# 324453    0.0867
# 324454    0.1649
# 324455    0.0699
# 324456    0.1924
# 324457    0.1049
# 324458    0.1559
# 324459    0.0819
# 324460    0.0949
# 324461    0.0749
# 324462    0.0949
# 324463    0.1199
# 324464    0.0867
# 324465    0.1924
# 324466    0.1239
# 324467       NaN
# ...

# %% [markdown]
# --->Removing months from column 'Initial_Loan_Term_Months'

# %%
LoanTerm=df['Initial_Loan_Term_Months'][0:]

# %%
LT1=LoanTerm.str.replace(' months', '')

# %%
LT1
# Out:
# 0          36
# 1          36
# 2          36
# 3          36
# 4          36
# 5          36
# 6          36
# 7          36
# 8          36
# 9          36
# 10         36
# 11         36
# 12         36
# 13         36
# 14         36
# 15         36
# 16         36
# 17         36
# 18         36
# 19         36
# 20         36
# 21         60
# 22         36
# 23         36
# 24         36
# 25         36
# 26         36
# 27         36
# 28         36
# 29         36
#          ...
# 324447     36
# 324448     36
# 324449     36
# 324450     36
# 324451     36
# 324452     60
# 324453     60
# 324454     36
# 324455     36
# 324456     36
# 324457     36
# 324458     36
# 324459     36
# 324460     36
# 324461     36
# 324462     36
# 324463     36
# 324464     36
# 324465     60
# 324466     36
# 324467     60
# 324468     36
# 324469     36
# 324470     36
# 324471     60
# 324472     36
# 324473     36
# 324474     36
# 324475     60
# 324476     60
# ...

# %%
len(df)
# Out:
# 324477

# %%
LT2 = [ x[:-1] for x in LT1 ]

# %%
df['Initial_Loan_Term_Months'] =LT2

# %%
df.describe()
# Out:
#        Interest_Rate          Loan_ID      Borrower_ID  Monthly_Payment
# count  274975.000000    324477.000000    324477.000000    324477.000000
# mean        0.138298  13145661.158156  14673129.804572       432.947560
# std         0.043678  10875525.606518  11658777.603057       243.602423
# min         0.054200     54734.000000     70699.000000        15.690000
# 25%         0.109900   3703284.000000   4584336.000000       257.870000
# 50%         0.136600  10122866.000000  11956936.000000       380.680000
# 75%         0.164900  20751084.000000  23021691.000000       567.780000
# max         0.260600  38098114.000000  40860827.000000      1409.990000

# %% [markdown]
# --->Some of the value for column 'Last_Payment_Total' has mis value 'Jun-15' whicl should be eliminated

# %%
df= df[df.Last_Payment_Total != 'Jun-15']

# %%
len(df)
# Out:
# 324073

# %% [markdown]
# Filling missing values

# %%
df.Interest_Rate.mean()
# Out:
# 0.13829823725818405

# %%
df.Interest_Rate.fillna(value=df.Interest_Rate.mean())
# Out:
# 0         0.118900
# 1         0.107100
# 2         0.169900
# 3         0.135700
# 4         0.190500
# 5         0.142600
# 6         0.078800
# 7         0.098800
# 8         0.111400
# 9         0.122100
# 10        0.134700
# 11        0.132400
# 12        0.085900
# 13        0.071400
# 14        0.086300
# 15        0.110300
# 16        0.138298
# 17        0.089400
# 18        0.103900
# 19        0.151300
# 20        0.080000
# 21        0.153300
# 22        0.086300
# 23        0.135500
# 24        0.138298
# 25        0.122900
# 26        0.090100
# 27        0.074300
# 28        0.074300
# 29        0.074300
#             ...
# 324447    0.081900
# 324448    0.192400
# 324449    0.119900
# 324450    0.129900
# 324451    0.081900
# 324452    0.192400
# 324453    0.086700
# 324454    0.164900
# 324455    0.069900
# 324456    0.192400
# 324457    0.104900
# 324458    0.155900
# 324459    0.081900
# 324460    0.094900
# 324461    0.074900
# 324462    0.094900
# ...

# %%
df.dropna()
# Out:
#         Interest_Rate   Loan_ID  Borrower_ID Loan_Amount_Requested  \
# 49439          0.1580   1501454      1762455                  1500
# 50303          0.2295   1517497      1780257                  1882
# 50940          0.1433   1526873      1791254                  1000
# 52103          0.1777   1546003      1811681                  1000
# 58065          0.0890   1685390      1967591                   630
# 59345          0.1875   1826223      2128538                  1600
# 61592          0.1580   2185057      2557903                   457
# 62449          0.1212   2286198      2708458                   800
# 64005          0.1580   2369452      2832030                  3000
# 65486          0.1531   2487044      2979394                   480
# 66277          0.1580   2826139      3408571                  1500
# 66426          0.1212   2827709      3410306                  2067
# 66678          0.1409   2836652      3419126                  1000
# ...

# %%
len(df)
# Out:
# 324073

# %% [markdown]
# ==>Pearson Correlation ,it can find the relationship between two numerical variables

# %%
df.corr(method='pearson', min_periods=1)
# Out:
#                  Interest_Rate   Loan_ID  Borrower_ID  Monthly_Payment
# Interest_Rate         1.000000 -0.030919    -0.028741         0.150205
# Loan_ID              -0.030919  1.000000     0.997314         0.036307
# Borrower_ID          -0.028741  0.997314     1.000000         0.038974
# Monthly_Payment       0.150205  0.036307     0.038974         1.000000

# %% [markdown]
# From here we know that Interest rate and Loanid,borrower-id are weekly correlated whereas Monthly payment is strongly correlated

# %% [markdown]
# Lets find out the correlation between other independent features and dependent feature Interest rate by first converting categorical variables to numerical variables

# %%
df.columns
# Out:
# Index([u'Interest_Rate', u'Loan_ID', u'Borrower_ID', u'Loan_Amount_Requested',
#        u'Loan_Amount_Funded', u'Loan_Amount_Funded_by_Investors',
#        u'Initial_Loan_Term_Months', u'Monthly_Payment', u'Loan_Grade',
#        u'Sub_Loan_Grade', u'Employer', u'Length_Employed', u'Home_Owner?',
#        u'Annual_Income', u'Income_Verified', u'Month_Issued',
#        u'Current_Status', u'Payment_Plan_Ind', u'Loan_Description',
#        u'Purpose_Of_Loan', u'Loan_Title', u'Zip_3', u'State',
#        u'Debt_To_Income', u'Number_Delinqueny_2yrs', u'Month_Earliest_Credit',
#        u'Inquiries_Last_6Mo', u'Months_Since_Deliquency',
#        u'Months_Since_Record', u'Number_Open_Accounts', u'Public_Record_Count',
#        u'Revolving_Balance', u'Revolving_Utilization', u'Total_Accounts',
#        u'Initial_Status', u'Outstanding_Principal',
#        u'Outstanding_Principal_Remaining', u'Total_Payment',
#        u'Total_Payment_Funded', u'Total_Received', u'Total_Received_Interest',
# ...

# %%
len(df)
# Out:
# 324073

# %% [markdown]
# #Converting categorical values into continuous values
# Taking into consideration for calculating interest rate
# Choose colums :Loan_Amount_Funded
#                Monthly_Payment
#                Loan_Grade
#                Total_Received_Late_Fees
#                Last_Payment_Total
#                Initial_Loan_Term_Month

# %%
X = pd.DataFrame()
X['Loan_Amount_Funded'] = df['Loan_Amount_Funded']
X['Monthly_Payment'] = df['Monthly_Payment']
X['Loan_Grade']=df['Loan_Grade']
#X['Total_Received_Late_Fees']=df['Total_Received_Late_Fees']
#X['Total_Received'] = df['Total_Received']
#X['Last_Payment_Total']=df['Last_Payment_Total']
#X['Last_Payment_Total']=df['Last_Payment_Total']
X['Initial_Loan_Term_Months'] = df['Initial_Loan_Term_Months']
#X['Annual_Income']=df['Annual_Income']
X['Interest_Rate'] = df['Interest_Rate']

# %%
y = X['Interest_Rate']
X = X.drop(['Interest_Rate'], axis=1)

# %%
# Make train and test datasets
from sklearn.cross_validation import train_test_split
import numpy as np
np.random.seed(100)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.63)

# %%
len(X_train)
# Out:
# 119907

# %%
X.count()
# Out:
# Loan_Amount_Funded          324073
# Monthly_Payment             324073
# Loan_Grade                  274586
# Initial_Loan_Term_Months    324073
# dtype: int64

# %%
X_train = X_train.join(pd.get_dummies(df.Loan_Grade, prefix='Grade'))

# %%
X_train= X_train.drop(['Loan_Grade', 'Grade_G'], axis=1)

# %%
X_train = X_train.join(pd.get_dummies(df.Loan_Amount_Funded, prefix='Amount_Funded'))

# %%
X_train.head()
# Out:
#        Loan_Amount_Funded  Monthly_Payment Initial_Loan_Term_Months  Grade_0  \
# 171442              23000           599.43                        6        0
# 23054               10000           344.95                        3        0
# 95905                6000           199.63                        3        0
# 49366               12000           287.44                        6        0
# 142294               8400           285.75                        3        0
#
#         Grade_A  Grade_B  Grade_C  Grade_D  Grade_E  Grade_F  \
# 171442        0        0        0        0        0        0
# 23054         0        0        1        0        0        0
# 95905         0        1        0        0        0        0
# 49366         0        0        0        0        0        0
# 142294        0        1        0        0        0        0
#
#                ...          Amount_Funded_9750  Amount_Funded_9775  \
# ...

# %%
X_train= X_train.drop(['Loan_Amount_Funded','Amount_Funded_9825'], axis=1)

# %%
X_train['Initial_Loan_Term_Months'] = pd.get_dummies(X_train.Initial_Loan_Term_Months)

# %% [markdown]
# X.corr(method='pearson', min_periods=1)

# %%
len(X_train)
# Out:
# 119907

# %%
len(X_train.columns)
# Out:
# 1344

# %%
X_train
# Out:
#         Monthly_Payment  Initial_Loan_Term_Months  Grade_0  Grade_A  Grade_B  \
# 171442           599.43                         0        0        0        0
# 23054            344.95                         1        0        0        0
# 95905            199.63                         1        0        0        1
# 49366            287.44                         0        0        0        0
# 142294           285.75                         1        0        0        1
# 87678            677.94                         0        0        0        0
# 179078           470.56                         1        0        0        1
# 301385           113.19                         1        0        0        0
# 24344            423.11                         0        0        0        0
# 321749           417.17                         0        0        0        0
# 143350           243.01                         1        0        0        0
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators=100, oob_score=True, random_state=42)
model.fit(X_train, y_train)

# %% [markdown]
# model.predict(X_test)

# %%
### Grid Search
from sklearn.grid_search import GridSearchCV
n_estimators = [300,400,500]
max_features = ['auto', 'sqrt','log2']
min_samples_split = [3,5,7]


rfc = RandomForestRegressor(n_jobs=1)
#Parameters of pipelines can be set using ‘__’ separated parameter names:
estimator = GridSearchCV(rfc,
                         dict(n_estimators=n_estimators,
                              max_features=max_features,
                              min_samples_split=min_samples_split
                              ), cv=None, n_jobs=-1)

# %%
estimator.fit(X_train, y_train)

# %%
estimator.best_estimator_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-108-19537099172f> in <module>()
# ----> 1 estimator.best_estimator_
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_estimator_'

# %% [markdown]
# rfc_best=estimator.best_estimator_

# %% [markdown]
# y_hat

# %% [markdown]
# mean_squared_error(y_test, y_hat)

# %% [markdown]
# r2_score(y_test, y_hat)

# %% [markdown]
# Reading TEST.CSV

# %%
df_test=pd.read_csv("D:\UIS-LEARN\Spring 2016/MidtermData/midterm_test.csv")
df_test.head()
# Out:
# C:\Users\anusha\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2902: DtypeWarning: Columns (13,28,29,30,31,37,38,39,40,41,42,43,50) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0   Loan_ID  Borrower_ID Loan_Amount_Requested Loan_Amount_Funded  \
# 0           0  15671090     17763514                $6,000             $6,000
# 1           1   7699533      9401088                $4,375             $4,375
# 2           2  12826375     14848495               $17,500            $17,500
# 3           3   6838614      8460512               $10,625            $10,625
# 4           4  17002617     19135146               $16,000            $16,000
#
#   Loan_Amount_Funded_by_Investors Initial_Loan_Term_Months  Monthly_Payment  \
# 0                          $5,950                36 months           202.14
# ...

# %%
len(df_test.columns)
# Out:
# 51

# %%
df_test.describe()
# Out:
#           Unnamed: 0          Loan_ID      Borrower_ID  Monthly_Payment
# count  117987.000000    117987.000000    117987.000000    117987.000000
# mean    58993.000000  13192185.767390  14718310.362506       432.902721
# std     34060.057443  10914425.400505  11699633.091690       243.303335
# min         0.000000     57245.000000     73673.000000        16.470000
# 25%     29496.500000   3701986.000000   4582226.500000       257.050000
# 50%     58993.000000  10130960.000000  11964760.000000       381.040000
# 75%     88489.500000  20782505.000000  23052289.000000       567.190000
# max    117986.000000  37841931.000000  40605012.000000      1408.130000

# %% [markdown]
# --->Eliminating $ sign from column 'Loan_Amount_Funded'

# %%
ldb_test= df_test.reset_index()
LoanGiven_test=df_test['Loan_Amount_Funded'][0:]

# %%
lg_test=LoanGiven_test.str.replace(',', '')

# %%
lg2_test=lg_test.str.lstrip('$')

# %%
Lg_test = [ x[:-1] for x in lg2_test ]

# %%
df_test['Loan_Amount_Funded'] =lg2_test

# %% [markdown]
# --->Eliminating $ sign from column 'Loan_Amount_Requested'

# %%
LoanRequested=df_test['Loan_Amount_Requested'][0:]

# %%
lr1_test=LoanRequested.str.replace(',', '')

# %%
lr2_test=lr1_test.str.lstrip('$')

# %%
LR_test = [ x[:-1] for x in lr2_test ]

# %%
df_test['Loan_Amount_Requested'] =LR_test

# %% [markdown]
# --->Eliminating $ sign from column 'Loan_Amount_Funded_by_Investors'

# %%
LI_test=df_test['Loan_Amount_Funded_by_Investors'][0:]

# %%
li1_test=LI_test.str.replace(',', '')

# %%
li2_test=li1_test.str.lstrip('$')

# %%
LI1_test = [ x[:-1] for x in li2_test ]

# %%
df_test['Loan_Amount_Funded_by_Investors'] =LI1_test

# %% [markdown]
# --->Removing months from column 'Initial_Loan_Term_Months'

# %%
LoanTerm=df_test['Initial_Loan_Term_Months'][0:]

# %%
LT1_test=LoanTerm.str.replace(' months', '')

# %%
LT2_test= [ x[:-1] for x in LT1_test ]

# %%
df_test['Initial_Loan_Term_Months'] =LT2_test

# %% [markdown]
# df_test= df_test[df_test.Last_Payment_Total != 'Jun-15']

# %% [markdown]
# df_test= df_test[df_test.Last_Payment_Total != 'May-15']

# %% [markdown]
# df_test[df_test.Total_Received == 'f']

# %% [markdown]
# df_test= df_test[df_test.Total_Received!= 'f']

# %% [markdown]
# df_test= df_test[df_test.Total_Received!= '$32.99<br/>Sears']

# %% [markdown]
# df_test= df_test.dropna(axis=0)

# %%
df_test['Last_Payment_Total'].value_counts()
# Out:
# 336.9       268
# 327.34      265
# 0           226
# 332.1       208
# 491.01      180
# 392.81      165
# 334.49      161
# 608.72      156
# 269.52      153
# 330.57      147
# 304.36      134
# 168.45      134
# 317.54      133
# 673.79      129
# 404.27      128
# 498.15      125
# 635.07      123
# 261.88      122
# 289.34      122
# 654.68      121
# 196.41      120
# 167.25      118
# Jun-15      117
# 341.68      115
# 365.23      114
# 312.91      113
# 381.04      110
# 456.54      108
# 501.74      108
# 476.3       107
#            ...
# 375.67        1
# 96.5          1
# 9971.8        1
# 613.49        1
# 2447.05       1
# 772.69        1
# 11401.55      1
# 17039.86      1
# 6611.48       1
# 933.63        1
# 155.21        1
# 375.69        1
# 749.08        1
# 2809.78       1
# 756.45        1
# 203.36        1
# 749.01        1
# 10953.44      1
# 6883.77       1
# 4154.98       1
# 1398.06       1
# 343.94        1
# 325.08        1
# 562.94        1
# ...

# %%
df.dtypes
# Out:
# Interest_Rate                      float64
# Loan_ID                              int64
# Borrower_ID                          int64
# Loan_Amount_Requested               object
# Loan_Amount_Funded                  object
# Loan_Amount_Funded_by_Investors     object
# Initial_Loan_Term_Months            object
# Monthly_Payment                    float64
# Loan_Grade                          object
# Sub_Loan_Grade                      object
# Employer                            object
# Length_Employed                     object
# Home_Owner?                         object
# Annual_Income                       object
# Income_Verified                     object
# Month_Issued                        object
# Current_Status                      object
# Payment_Plan_Ind                    object
# Loan_Description                    object
# Purpose_Of_Loan                     object
# Loan_Title                          object
# Zip_3                               object
# ...

# %%
df_test['Total_Received_Late_Fees'].value_counts()
# Out:
# 0.0                   99628
# 0.0                   15495
# 0                       552
# 15.0                    327
# 15.0                     55
# 30.0                     35
# 45.0                      6
# 30.0                      6
# 15.89                     4
# 17.41                     4
# 16.72                     3
# 18.2                      3
# 21.31                     3
# 15.6                      3
# 25.32                     3
# 12000.0                   3
# 34.34                     3
# 10000.0                   3
# 33.86                     3
# 20.6                      3
# 60.0                      3
# 15000.0                   3
# 17.2                      3
# 16.64                     2
# 26.71                     2
# 15.82                     2
# 26.48                     2
# 18.87                     2
# 16.06                     2
# 20000.0                   2
#                       ...
# 14.9871991808             1
# 14.9654587323             1
# ...

# %%
df_test['Initial_Loan_Term_Months'].value_counts()
# Out:
#  3    85524
#  6    32463
# Name: Initial_Loan_Term_Months, dtype: int64

# %%
Result=pd.DataFrame()

# %%
Result['Id'] = df_test['Unnamed: 0']

# %%
Result['Id'].count()
# Out:
# 117987

# %%
X1 = pd.DataFrame()
X1['Loan_Amount_Funded'] = df_test['Loan_Amount_Funded']
#X1['Total_Received'] = df_test['Total_Received']
X1['Monthly_Payment'] = df_test['Monthly_Payment']
X1['Loan_Grade']=df_test['Loan_Grade']
#X1['Total_Received_Late_Fees']=df_test['Total_Received_Late_Fees']

#X1['Last_Payment_Total']=df_test['Last_Payment_Total']
X1['Initial_Loan_Term_Months'] = df_test['Initial_Loan_Term_Months']

# %%
X1
# Out:
#        Loan_Amount_Funded  Monthly_Payment Loan_Grade Initial_Loan_Term_Months
# 0                    6000           202.14          B                        3
# 1                    4375           161.53          D                        3
# 2                   17500           413.03          C                        6
# 3                   10625           342.79          B                        3
# 4                   16000           541.81          C                        3
# 5                    5000           160.57          B                        3
# 6                   30000           992.28          B                        3
# 7                    6000           205.98          C                        3
# 8                    9000           299.45          B                        3
# 9                    9000           299.45          B                        3
# 10                   7500           257.32          C                        3
# ...

# %%
def describe_categorical(X1):
    """
    Just like .describe(), but returns the results for
    categorical variables only.
    """
    from IPython.display import display, HTML
    display(HTML(X1[X1.columns[X1.dtypes == "object"]].describe().to_html()))

# %%
describe_categorical(X1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Loan_Amount_Funded</th>
#       <th>Loan_Grade</th>
#       <th>Initial_Loan_Term_Months</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>117987</td>
#       <td>100041</td>
#       <td>117987</td>
#     </tr>
#     <tr>
#       <th>unique</th>
#       <td>1261</td>
#       <td>8</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>top</th>
#       <td>10000</td>
#       <td>B</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>freq</th>
#       <td>8408</td>
#       <td>29543</td>
#       <td>85524</td>
#     </tr>
#   </tbody>
# </table>

# %%
X1.Initial_Loan_Term_Months.value_counts()
# Out:
#  3    85524
#  6    32463
# Name: Initial_Loan_Term_Months, dtype: int64

# %%
X1.Loan_Grade.value_counts()
# Out:
# B    29543
# C    27030
# D    16268
# A    16096
# E     7529
# F     2879
# G      692
# 0        4
# Name: Loan_Grade, dtype: int64

# %%
X1 = X1.join(pd.get_dummies(df_test.Loan_Amount_Funded, prefix='Amount_Funded'))
X1= X1.drop(['Loan_Amount_Funded', 'Amount_Funded_9900'], axis=1)

# %%
X1 = X1.join(pd.get_dummies(df_test.Loan_Grade, prefix='Grade'))
X1= X1.drop(['Grade_G', 'Loan_Grade'], axis=1)

# %%
X1['Initial_Loan_Term_Months'] = pd.get_dummies(X1.Initial_Loan_Term_Months)

# %%
set(X_train.columns) - set(X1.columns)
# Out:
# {'Amount_Funded_1075',
#  'Amount_Funded_1225',
#  'Amount_Funded_1425',
#  'Amount_Funded_1725',
#  'Amount_Funded_20025',
#  'Amount_Funded_25125',
#  'Amount_Funded_26175',
#  'Amount_Funded_26225',
#  'Amount_Funded_26450',
#  'Amount_Funded_26525',
#  'Amount_Funded_26700',
#  'Amount_Funded_26875',
#  'Amount_Funded_27275',
#  'Amount_Funded_27350',
#  'Amount_Funded_27550',
#  'Amount_Funded_27775',
#  'Amount_Funded_27825',
#  'Amount_Funded_27925',
#  'Amount_Funded_27950',
#  'Amount_Funded_28075',
#  'Amount_Funded_28400',
#  'Amount_Funded_28525',
#  'Amount_Funded_28575',
#  'Amount_Funded_28675',
#  'Amount_Funded_28850',
#  'Amount_Funded_29075',
#  'Amount_Funded_29275',
#  'Amount_Funded_29425',
#  'Amount_Funded_29475',
#  'Amount_Funded_29825',
#  'Amount_Funded_30050',
#  'Amount_Funded_30150',
#  'Amount_Funded_30325',
#  'Amount_Funded_30450',
#  'Amount_Funded_30475',
#  'Amount_Funded_30525',
#  'Amount_Funded_30650',
#  'Amount_Funded_30675',
# ...

# %%
X1["Last_Payment_Total_1020.42"] = 0
X1["Last_Payment_Total_151.3"] = 0
X1["Total_Received_1237.89"] = 0
X1["Total_Received_2045.83"] = 0
X1["Total_Received_Late_Fees_15.0"] = 0
X1["Total_Received_2021.31"] = 0

# %%
 X1['Total_Received_Late_Fees_15.0']=0

# %%
len(X1.columns)
# Out:
# 1275

# %%
y_hat1 =rfc_best.predict(X1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-107-97b1d5c2683b> in <module>()
# ----> 1 y_hat1 =rfc_best.predict(X1)
#
# NameError: name 'rfc_best' is not defined

# %%
y_hat1
# Out:
# array([ 0.14780193,  0.14746958,  0.12886655,  0.17985699,  0.10115212,
#         0.10123566,  0.12431855,  0.10115212,  0.12823099,  0.10115212,
#         0.14868641,  0.124377  ,  0.13050398,  0.13250982,  0.14942351,
#         0.10115212,  0.18540215,  0.13202086,  0.18741543,  0.14780193,
#         0.1015602 ,  0.17965064,  0.15037116,  0.10123566,  0.10115212,
#         0.14780193,  0.15022822,  0.10115212,  0.12920963,  0.10115212,
#         0.18116434,  0.10115212,  0.14952488,  0.10115212,  0.23072799,
#         0.10115212,  0.15157395,  0.14881797,  0.10115212,  0.12929746,
#         0.10115212,  0.22996466,  0.1492022 ,  0.10115212,  0.14760258,
#         0.13050134,  0.22882601,  0.10115212,  0.12754077,  0.13113913,
#         0.14804478,  0.1002    ,  0.18230981,  0.12437326,  0.12701768,
#         0.10007679,  0.1002    ,  0.14559307,  0.14702091,  0.14823692,
#         0.1002    ,  0.18587752,  0.12522754,  0.13190112,  0.10007679,
# ...

# %%
y_hat1
# Out:
# array([ 0.00159829,  0.00159829,  0.00125712,  0.00168077,  0.00128894,
#         0.00128894,  0.00125712,  0.00128894,  0.00125712,  0.00128894,
#         0.00159829,  0.00125712,  0.00125712,  0.00125712,  0.00159829,
#         0.00128894,  0.00168077,  0.00125712,  0.00168077,  0.00159829,
#         0.00128894,  0.00168077,  0.00159829,  0.00128894,  0.00128894,
#         0.00159829,  0.00159829,  0.00128894,  0.00125712,  0.00128894,
#         0.00168077,  0.00128894,  0.00159829,  0.00128894,  0.00167729,
#         0.00128894,  0.00159829,  0.00159829,  0.00128894,  0.00125712,
#         0.00128894,  0.00167729,  0.00159829,  0.00128894,  0.00159829,
#         0.00125712,  0.00167729,  0.00128894,  0.00125712,  0.00125712,
#         0.00159829,  0.00128894,  0.00168077,  0.00125712,  0.00125712,
#         0.00128894,  0.00128894,  0.00159829,  0.00159829,  0.00159829,
#         0.00128894,  0.00168077,  0.00125712,  0.00125712,  0.00128894,
# ...

# %%
Result = pd.DataFrame()

# %%
Result['Id'] = df_test['Unnamed: 0']

# %%
 df_test['Unnamed: 0']
# Out:
# 55            55
# 720          720
# 2097        2097
# 2627        2627
# 3902        3902
# 4025        4025
# 4249        4249
# 4738        4738
# 5153        5153
# 5705        5705
# 9907        9907
# 10668      10668
# 11811      11811
# 13035      13035
# 13220      13220
# 13701      13701
# 14589      14589
# 14887      14887
# 14932      14932
# 15205      15205
# 15304      15304
# 15512      15512
# 15568      15568
# 15758      15758
# 16072      16072
# 17267      17267
# 17400      17400
# 17588      17588
# 18747      18747
# 19135      19135
#            ...
# 94070      94070
# 94590      94590
# 97951      97951
# 98677      98677
# 99264      99264
# 99769      99769
# 100100    100100
# 100758    100758
# 102520    102520
# 102889    102889
# 104958    104958
# 105024    105024
# 105636    105636
# 105952    105952
# 108222    108222
# 108413    108413
# 109409    109409
# 110188    110188
# 112611    112611
# 112753    112753
# 112854    112854
# ...

# %%
Result['Rate'] = y_hat1

# %%
# Out:
#             Id      Rate
# 55          55  0.147802
# 720        720  0.147470
# 2097      2097  0.128867
# 2627      2627  0.179857
# 3902      3902  0.101152
# 4025      4025  0.101236
# 4249      4249  0.124319
# 4738      4738  0.101152
# 5153      5153  0.128231
# 5705      5705  0.101152
# 9907      9907  0.148686
# 10668    10668  0.124377
# 11811    11811  0.130504
# 13035    13035  0.132510
# 13220    13220  0.149424
# 13701    13701  0.101152
# 14589    14589  0.185402
# 14887    14887  0.132021
# 14932    14932  0.187415
# 15205    15205  0.147802
# 15304    15304  0.101560
# 15512    15512  0.179651
# 15568    15568  0.150371
# 15758    15758  0.101236
# 16072    16072  0.101152
# 17267    17267  0.147802
# 17400    17400  0.150228
# 17588    17588  0.101152
# 18747    18747  0.129210
# 19135    19135  0.101152
# ...        ...       ...
# 94070    94070  0.101152
# 94590    94590  0.237125
# 97951    97951  0.101152
# 98677    98677  0.101152
# 99264    99264  0.101236
# ...

# %%
Result.to_csv("D:\UIS-LEARN\Spring 2016/MidtermData/submission.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-374bb937d79d> in <module>()
# ----> 1 Result.to_csv("D:\UIS-LEARN\Spring 2016/MidtermData/submission.csv", index=False)
#
# NameError: name 'Result' is not defined
